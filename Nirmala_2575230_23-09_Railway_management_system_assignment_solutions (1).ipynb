# %%
import mysql.connector

# Define the data to insert
data_to_insert = [
    ('vande bharat', '08:00:00', '12:00:00', 'bangalore', 'delhi'),
    ('shatabdi', '09:30:00', '13:30:00', 'hubli', 'pune'),
    ('Duronto express', '10:45:00', '14:45:00', 'mumbai', 'belgaum')
]

# Establish a connection to the MySQL database
db = mysql.connector.connect(
    host="127.0.0.1",
    user="task",
    password="nimmi",
    database="trains"
)

# Create a cursor to execute SQL queries
cursor = db.cursor()

# Define the SQL query to insert data
insert_query = "INSERT INTO Trains (TrainName, DepartureTime, ArrivalTime, SourceStation, DestinationStation) VALUES (%s, %s, %s, %s, %s)"

# Execute the query for each set of data
try:
    cursor.executemany(insert_query, data_to_insert)
    db.commit()  # Commit the changes to the database
    print("Data inserted successfully.")
except Exception as e:
    db.rollback()  # Rollback the transaction in case of an error
    print("Error:", e)

# Close the database connection
db.close()
# Out:
# Data inserted successfully.

# %%
import mysql.connector

db = mysql.connector.connect(
    host="127.0.0.1",
    user="task",
    password="nimmi",
    database="trains"
)
cursor = db.cursor()
cursor.execute("select * from trains")
for i in cursor:
    print(i)
# Out:
# (1, 'vande bharat', datetime.timedelta(seconds=28800), datetime.timedelta(seconds=43200), 'bangalore', 'delhi')
# (2, 'shatabdi', datetime.timedelta(seconds=34200), datetime.timedelta(seconds=48600), 'hubli', 'pune')
# (3, 'Duronto express', datetime.timedelta(seconds=38700), datetime.timedelta(seconds=53100), 'mumbai', 'belgaum')

# %%
import mysql.connector

# Define the data to insert (TrainID, Class, FareAmount)
fares_to_insert = [
    (1, 'Sleeper', 470.00),
    (1, 'AC', 795.00),
    (2, 'Sleeper', 460.00),
    (2, 'AC', 880.00),
    (3, 'Sleeper', 520.00),
    (3, 'AC', 980.00)
]

# Establish a connection to the MySQL database
db = mysql.connector.connect(
    host="127.0.0.1",
    user="task",
    password="nimmi",
    database="trains"
)

# Create a cursor to execute SQL queries
cursor = db.cursor()

# Define the SQL query to insert fares data
insert_query = "INSERT INTO Fares (TrainID, Class, FareAmount) VALUES (%s, %s, %s)"

# Execute the query for each set of data
try:
    cursor.executemany(insert_query, fares_to_insert)
    db.commit()  # Commit the changes to the database
    print("Fares data inserted successfully.")
except Exception as e:
    db.rollback()  # Rollback the transaction in case of an error
    print("Error:", e)

# Close the database connection
db.close()
# Out:
# Fares data inserted successfully.

# %% [markdown]
# import mysql.connector
#
# db = mysql.connector.connect(
#     host="127.0.0.1",
#     user="task",
#     password="nimmi",
#     database="trains"
# )
# cursor = db.cursor()
# cursor.execute("select * from fares")
# for i in cursor:
#     print(i)

# %% [markdown]
# # task-1: passengers Booking

# %%
import mysql.connector

# Connect to the MySQL database
db = mysql.connector.connect(
    host="127.0.0.1",
    user="task",
    password="nimmi",
    database="trains"
)

# Create a cursor to interact with the database
cursor = db.cursor()

max_seats = 8
def book_ticket(train_id, passenger_name, travel_date, ticket_class):
    try:
        # Check seat availability
        cursor.execute("SELECT COUNT(*) FROM Bookings WHERE TrainID = %s AND TravelDate = %s", (train_id, travel_date))
        count = cursor.fetchone()[0]
        
        if count >= max_seats:
            print("No available seats for the selected train and date.")
            return

        # Insert booking record
        cursor.execute("INSERT INTO Bookings (TrainID, PassengerName, TravelDate, Class, Status) VALUES (%s, %s, %s, %s, %s)",
                       (train_id, passenger_name, travel_date, ticket_class, 'Confirmed'))
        db.commit()
        print("Ticket booked successfully!")

    except Exception as e:
        print("Error:", e)

# Task 2: Reservation Cancellation
def cancel_booking(booking_id):
    try:
        cursor.execute("UPDATE Bookings SET Status = 'Cancelled' WHERE BookingID = %s", (booking_id,))
        db.commit()
        print("Booking cancelled successfully!")

    except Exception as e:
        print("Error:", e)

# Task 3: Fare Checking
def check_fare(train_id, ticket_class):
    try:
        cursor.execute("SELECT FareAmount FROM Fares WHERE TrainID = %s AND Class = %s", (train_id, ticket_class))
        fare = cursor.fetchone()[0]
        print("Fare for the selected class:", fare)

    except Exception as e:
        print("Error:", e)

# Task 4: Booking History
def booking_history(passenger_name):
    try:
        cursor.execute("SELECT * FROM Bookings WHERE PassengerName = %s", (passenger_name,))
        bookings = cursor.fetchall()
        
        if not bookings:
            print("No booking history found for the passenger.")
        else:
            for booking in bookings:
                print("BookingID:", booking[0])
                print("TrainID:", booking[1])
                print("PassengerName:", booking[2])
                print("TravelDate:", booking[3])
                print("Class:", booking[4])
                print("Status:", booking[5])
                print()

    except Exception as e:
        print("Error:", e)

# Task 5: Train Availability
def train_availability(source_station, destination_station):
    try:
        cursor.execute("SELECT * FROM Trains WHERE SourceStation = %s AND DestinationStation = %s",
                       (source_station, destination_station))
        available_trains = cursor.fetchall()
        
        if not available_trains:
            print("No available trains for the selected route.")
        else:
            for train in available_trains:
                print("TrainID:", train[0])
                print("TrainName:", train[1])
                print("DepartureTime:", train[2])
                print("ArrivalTime:", train[3])
                print()

    except Exception as e:
        print("Error:", e)

# Task 6: Menu and User Interaction (Sample Menu)
while True:
    print("Railway Management System")
    print("1. Book Ticket")
    print("2. Cancel Booking")
    print("3. Check Fare")
    print("4. Booking History")
    print("5. Train Availability")
    print("6. Exit")
    
    choice = input("Enter your choice: ")

    if choice == '1':
        train_id = input("Enter TrainID: ")
        passenger_name = input("Enter Passenger Name: ")
        travel_date = input("Enter Travel Date (YYYY-MM-DD): ")
        ticket_class = input("Enter Class: ")
        book_ticket(train_id, passenger_name, travel_date, ticket_class)
    
    elif choice == '2':
        booking_id = input("Enter BookingID to can22cel: ")
        cancel_booking(booking_id)

    elif choice == '3':
        train_id = input("Enter TrainID: ")
        ticket_class = input("Enter Class: ")
        check_fare(train_id, ticket_class)

    elif choice == '4':
        passenger_name = input("Enter Passenger Name: ")
        booking_history(passenger_name)

    elif choice == '5':
        source_station = input("Enter Source Station: ")
        destination_station = input("Enter Destination Station: ")
        train_availability(source_station, destination_station)

    elif choice == '6':
        break

# Close the database connection
db.close()
# Out:
# Railway Management System
# 1. Book Ticket
# 2. Cancel Booking
# 3. Check Fare
# 4. Booking History
# 5. Train Availability
# 6. Exit
# Enter your choice: 1
# Enter TrainID: 1
# Enter Passenger Name: Nirmala
# Enter Travel Date (YYYY-MM-DD): 2023-09-27
# Enter Class: sleeper
# Ticket booked successfully!
# Railway Management System
# 1. Book Ticket
# 2. Cancel Booking
# 3. Check Fare
# 4. Booking History
# 5. Train Availability
# 6. Exit
# Enter your choice: 1
# Enter TrainID: 2
# Enter Passenger Name: Bhanuprakash
# Enter Travel Date (YYYY-MM-DD): 2023-09-25
# Enter Class: upper
# Ticket booked successfully!
# Railway Management System
# 1. Book Ticket
# 2. Cancel Booking
# 3. Check Fare
# 4. Booking History
# 5. Train Availability
# 6. Exit
# Enter your choice: 6

# %%
import mysql.connector

db = mysql.connector.connect(
    host="127.0.0.1",
    user="task",
    password="nimmi",
    database="trains"
)
cursor = db.cursor()
cursor.execute("select * from bookings")
for i in cursor:
    print(i)
# Out:
# (3, 1, 'Nirmala', datetime.date(2023, 9, 27), 'sleeper', 'Confirmed')
# (4, 2, 'Bhanuprakash', datetime.date(2023, 9, 25), 'upper', 'Confirmed')

# %%
import mysql.connector

# Connect to the MySQL database
db = mysql.connector.connect(
    host="127.0.0.1",
    user="task",
    password="nimmi",
    database="trains"
)

# Create a cursor to interact with the database
cursor = db.cursor()

max_seats = 8
def book_ticket(train_id, passenger_name, travel_date, ticket_class):
    try:
        # Check seat availability
        cursor.execute("SELECT COUNT(*) FROM Bookings WHERE TrainID = %s AND TravelDate = %s", (train_id, travel_date))
        count = cursor.fetchone()[0]
        
        if count >= max_seats:
            print("No available seats for the selected train and date.")
            return

        # Insert booking record
        cursor.execute("INSERT INTO Bookings (TrainID, PassengerName, TravelDate, Class, Status) VALUES (%s, %s, %s, %s, %s)",
                       (train_id, passenger_name, travel_date, ticket_class, 'Confirmed'))
        db.commit()
        print("Ticket booked successfully!")

    except Exception as e:
        print("Error:", e)

# Task 2: Reservation Cancellation
def cancel_booking(booking_id):
    try:
        cursor.execute("UPDATE Bookings SET Status = 'Cancelled' WHERE BookingID = %s", (booking_id,))
        db.commit()
        print("Booking cancelled successfully!")

    except Exception as e:
        print("Error:", e)

# Task 3: Fare Checking
def check_fare(train_id, ticket_class):
    try:
        cursor.execute("SELECT FareAmount FROM Fares WHERE TrainID = %s AND Class = %s", (train_id, ticket_class))
        fare = cursor.fetchone()[0]
        print("Fare for the selected class:", fare)

    except Exception as e:
        print("Error:", e)

# Task 4: Booking History
def booking_history(passenger_name):
    try:
        cursor.execute("SELECT * FROM Bookings WHERE PassengerName = %s", (passenger_name,))
        bookings = cursor.fetchall()
        
        if not bookings:
            print("No booking history found for the passenger.")
        else:
            for booking in bookings:
                print("BookingID:", booking[0])
                print("TrainID:", booking[1])
                print("PassengerName:", booking[2])
                print("TravelDate:", booking[3])
                print("Class:", booking[4])
                print("Status:", booking[5])
                print()

    except Exception as e:
        print("Error:", e)

# Task 5: Train Availability
def train_availability(source_station, destination_station):
    try:
        cursor.execute("SELECT * FROM Trains WHERE SourceStation = %s AND DestinationStation = %s",
                       (source_station, destination_station))
        available_trains = cursor.fetchall()
        
        if not available_trains:
            print("No available trains for the selected route.")
        else:
            for train in available_trains:
                print("TrainID:", train[0])
                print("TrainName:", train[1])
                print("DepartureTime:", train[2])
                print("ArrivalTime:", train[3])
                print()

    except Exception as e:
        print("Error:", e)

# Task 6: Menu and User Interaction (Sample Menu)
while True:
    print("Railway Management System")
    print("1. Book Ticket")
    print("2. Cancel Booking")
    print("3. Check Fare")
    print("4. Booking History")
    print("5. Train Availability")
    print("6. Exit")
    
    choice = input("Enter your choice: ")

    if choice == '1':
        train_id = input("Enter TrainID: ")
        passenger_name = input("Enter Passenger Name: ")
        travel_date = input("Enter Travel Date (YYYY-MM-DD): ")
        ticket_class = input("Enter Class: ")
        book_ticket(train_id, passenger_name, travel_date, ticket_class)
    
    elif choice == '2':
        booking_id = input("Enter BookingID to cancel: ")
        cancel_booking(booking_id)

    elif choice == '3':
        train_id = input("Enter TrainID: ")
        ticket_class = input("Enter Class: ")
        check_fare(train_id, ticket_class)

    elif choice == '4':
        passenger_name = input("Enter Passenger Name: ")
        booking_history(passenger_name)

    elif choice == '5':
        source_station = input("Enter Source Station: ")
        destination_station = input("Enter Destination Station: ")
        train_availability(source_station, destination_station)

    elif choice == '6':
        break
db.close()
# Out:
# Railway Management System
# 1. Book Ticket
# 2. Cancel Booking
# 3. Check Fare
# 4. Booking History
# 5. Train Availability
# 6. Exit
# Enter your choice: 2
# Enter BookingID to cancel: 4
# Booking cancelled successfully!
# Railway Management System
# 1. Book Ticket
# 2. Cancel Booking
# 3. Check Fare
# 4. Booking History
# 5. Train Availability
# 6. Exit
# Enter your choice: 2
# Enter BookingID to cancel: 4
# Booking cancelled successfully!
# Railway Management System
# 1. Book Ticket
# 2. Cancel Booking
# 3. Check Fare
# 4. Booking History
# 5. Train Availability
# 6. Exit
# Enter your choice: 6

# %%
import mysql.connector

db = mysql.connector.connect(
    host="127.0.0.1",
    user="task",
    password="nimmi",
    database="trains"
)
cursor = db.cursor()
cursor.execute("select * from bookings")
for i in cursor:
    print(i)
# Out:
# (3, 1, 'Nirmala', datetime.date(2023, 9, 27), 'sleeper', 'Confirmed')
# (4, 2, 'Bhanuprakash', datetime.date(2023, 9, 25), 'upper', 'Cancelled')

# %% [markdown]
# # task-3 : Checking fare

# %%
import mysql.connector

# Connect to the MySQL database
db = mysql.connector.connect(
    host="127.0.0.1",
    user="task",
    password="nimmi",
    database="trains"
)

# Create a cursor to interact with the database
cursor = db.cursor()

max_seats = 8
def book_ticket(train_id, passenger_name, travel_date, ticket_class):
    try:
        # Check seat availability
        cursor.execute("SELECT COUNT(*) FROM Bookings WHERE TrainID = %s AND TravelDate = %s", (train_id, travel_date))
        count = cursor.fetchone()[0]
        
        if count >= max_seats:
            print("No available seats for the selected train and date.")
            return

        # Insert booking record
        cursor.execute("INSERT INTO Bookings (TrainID, PassengerName, TravelDate, Class, Status) VALUES (%s, %s, %s, %s, %s)",
                       (train_id, passenger_name, travel_date, ticket_class, 'Confirmed'))
        db.commit()
        print("Ticket booked successfully!")

    except Exception as e:
        print("Error:", e)

# Task 2: Reservation Cancellation
def cancel_booking(booking_id):
    try:
        cursor.execute("UPDATE Bookings SET Status = 'Cancelled' WHERE BookingID = %s", (booking_id,))
        db.commit()
        print("Booking cancelled successfully!")

    except Exception as e:
        print("Error:", e)

# Task 3: Fare Checking
def check_fare(train_id, ticket_class):
    try:
        cursor.execute("SELECT FareAmount FROM Fares WHERE TrainID = %s AND Class = %s", (train_id, ticket_class))
        fare = cursor.fetchone()[0]
        print("Fare for the selected class:", fare)

    except Exception as e:
        print("Error:", e)

# Task 4: Booking History
def booking_history(passenger_name):
    try:
        cursor.execute("SELECT * FROM Bookings WHERE PassengerName = %s", (passenger_name,))
        bookings = cursor.fetchall()
        
        if not bookings:
            print("No booking history found for the passenger.")
        else:
            for booking in bookings:
                print("BookingID:", booking[0])
                print("TrainID:", booking[1])
                print("PassengerName:", booking[2])
                print("TravelDate:", booking[3])
                print("Class:", booking[4])
                print("Status:", booking[5])
                print()

    except Exception as e:
        print("Error:", e)

# Task 5: Train Availability
def train_availability(source_station, destination_station):
    try:
        cursor.execute("SELECT * FROM Trains WHERE SourceStation = %s AND DestinationStation = %s",
                       (source_station, destination_station))
        available_trains = cursor.fetchall()
        
        if not available_trains:
            print("No available trains for the selected route.")
        else:
            for train in available_trains:
                print("TrainID:", train[0])
                print("TrainName:", train[1])
                print("DepartureTime:", train[2])
                print("ArrivalTime:", train[3])
                print()

    except Exception as e:
        print("Error:", e)

# Task 6: Menu and User Interaction (Sample Menu)
while True:
    print("Railway Management System")
    print("1. Book Ticket")
    print("2. Cancel Booking")
    print("3. Check Fare")
    print("4. Booking History")
    print("5. Train Availability")
    print("6. Exit")
    
    choice = input("Enter your choice: ")

    if choice == '1':
        train_id = input("Enter TrainID: ")
        passenger_name = input("Enter Passenger Name: ")
        travel_date = input("Enter Travel Date (YYYY-MM-DD): ")
        ticket_class = input("Enter Class: ")
        book_ticket(train_id, passenger_name, travel_date, ticket_class)
    
    elif choice == '2':
        booking_id = input("Enter BookingID to cancel: ")
        cancel_booking(booking_id)

    elif choice == '3':
        train_id = input("Enter TrainID: ")
        ticket_class = input("Enter Class: ")
        check_fare(train_id, ticket_class)

    elif choice == '4':
        passenger_name = input("Enter Passenger Name: ")
        booking_history(passenger_name)

    elif choice == '5':
        source_station = input("Enter Source Station: ")
        destination_station = input("Enter Destination Station: ")
        train_availability(source_station, destination_station)

    elif choice == '6':
        break
db.close()
# Out:
# Railway Management System
# 1. Book Ticket
# 2. Cancel Booking
# 3. Check Fare
# 4. Booking History
# 5. Train Availability
# 6. Exit
# Enter your choice: 3
# Enter TrainID: 1
# Enter Class: sleeper
# Fare for the selected class: 470.00
# Railway Management System
# 1. Book Ticket
# 2. Cancel Booking
# 3. Check Fare
# 4. Booking History
# 5. Train Availability
# 6. Exit
# Enter your choice: 3
# Enter TrainID: 2
# Enter Class: upper
# Error: 'NoneType' object is not subscriptable
# Railway Management System
# 1. Book Ticket
# 2. Cancel Booking
# 3. Check Fare
# 4. Booking History
# 5. Train Availability
# 6. Exit
# Enter your choice: 1
# Enter TrainID: 3
# Enter Passenger Name: rinku
# Enter Travel Date (YYYY-MM-DD): 2023-09-28
# Enter Class: AC
# Ticket booked successfully!
# Railway Management System
# 1. Book Ticket
# 2. Cancel Booking
# 3. Check Fare
# 4. Booking History
# 5. Train Availability
# 6. Exit
# Enter your choice: 3
# Enter TrainID: 3
# Enter Class: AC
# Fare for the selected class: 980.00
# Railway Management System
# 1. Book Ticket
# 2. Cancel Booking
# 3. Check Fare
# 4. Booking History
# 5. Train Availability
# 6. Exit
# Enter your choice: 6

# %% [markdown]
# # Task 4: Booking History

# %%
# import mysql.connector

# Connect to the MySQL database
db = mysql.connector.connect(
    host="127.0.0.1",
    user="task",
    password="nimmi",
    database="trains"
)

# Create a cursor to interact with the database
cursor = db.cursor()

max_seats = 8
def book_ticket(train_id, passenger_name, travel_date, ticket_class):
    try:
        # Check seat availability
        cursor.execute("SELECT COUNT(*) FROM Bookings WHERE TrainID = %s AND TravelDate = %s", (train_id, travel_date))
        count = cursor.fetchone()[0]
        
        if count >= max_seats:
            print("No available seats for the selected train and date.")
            return

        # Insert booking record
        cursor.execute("INSERT INTO Bookings (TrainID, PassengerName, TravelDate, Class, Status) VALUES (%s, %s, %s, %s, %s)",
                       (train_id, passenger_name, travel_date, ticket_class, 'Confirmed'))
        db.commit()
        print("Ticket booked successfully!")

    except Exception as e:
        print("Error:", e)

# Task 2: Reservation Cancellation
def cancel_booking(booking_id):
    try:
        cursor.execute("UPDATE Bookings SET Status = 'Cancelled' WHERE BookingID = %s", (booking_id,))
        db.commit()
        print("Booking cancelled successfully!")

    except Exception as e:
        print("Error:", e)

# Task 3: Fare Checking
def check_fare(train_id, ticket_class):
    try:
        cursor.execute("SELECT FareAmount FROM Fares WHERE TrainID = %s AND Class = %s", (train_id, ticket_class))
        fare = cursor.fetchone()[0]
        print("Fare for the selected class:", fare)

    except Exception as e:
        print("Error:", e)

# Task 4: Booking History
def booking_history(passenger_name):
    try:
        cursor.execute("SELECT * FROM Bookings WHERE PassengerName = %s", (passenger_name,))
        bookings = cursor.fetchall()
        
        if not bookings:
            print("No booking history found for the passenger.")
        else:
            for booking in bookings:
                print("BookingID:", booking[0])
                print("TrainID:", booking[1])
                print("PassengerName:", booking[2])
                print("TravelDate:", booking[3])
                print("Class:", booking[4])
                print("Status:", booking[5])
                print()

    except Exception as e:
        print("Error:", e)

# Task 5: Train Availability
def train_availability(source_station, destination_station):
    try:
        cursor.execute("SELECT * FROM Trains WHERE SourceStation = %s AND DestinationStation = %s",
                       (source_station, destination_station))
        available_trains = cursor.fetchall()
        
        if not available_trains:
            print("No available trains for the selected route.")
        else:
            for train in available_trains:
                print("TrainID:", train[0])
                print("TrainName:", train[1])
                print("DepartureTime:", train[2])
                print("ArrivalTime:", train[3])
                print()

    except Exception as e:
        print("Error:", e)

# Task 6: Menu and User Interaction (Sample Menu)
while True:
    print("Railway Management System")
    print("1. Book Ticket")
    print("2. Cancel Booking")
    print("3. Check Fare")
    print("4. Booking History")
    print("5. Train Availability")
    print("6. Exit")
    
    choice = input("Enter your choice: ")

    if choice == '1':
        train_id = input("Enter TrainID: ")
        passenger_name = input("Enter Passenger Name: ")
        travel_date = input("Enter Travel Date (YYYY-MM-DD): ")
        ticket_class = input("Enter Class: ")
        book_ticket(train_id, passenger_name, travel_date, ticket_class)
    
    elif choice == '2':
        booking_id = input("Enter BookingID to cancel: ")
        cancel_booking(booking_id)

    elif choice == '3':
        train_id = input("Enter TrainID: ")
        ticket_class = input("Enter Class: ")
        check_fare(train_id, ticket_class)

    elif choice == '4':
        passenger_name = input("Enter Passenger Name: ")
        booking_history(passenger_name)

    elif choice == '5':
        source_station = input("Enter Source Station: ")
        destination_station = input("Enter Destination Station: ")
        train_availability(source_station, destination_station)

    elif choice == '6':
        break
db.close()

# %% [markdown]
# # Task 5: Train Availability

# %%
import mysql.connector

# Connect to the MySQL database
db = mysql.connector.connect(
    host="127.0.0.1",
    user="task",
    password="nimmi",
    database="trains"
)

# Create a cursor to interact with the database
cursor = db.cursor()

max_seats = 8
def book_ticket(train_id, passenger_name, travel_date, ticket_class):
    try:
        # Check seat availability
        cursor.execute("SELECT COUNT(*) FROM Bookings WHERE TrainID = %s AND TravelDate = %s", (train_id, travel_date))
        count = cursor.fetchone()[0]
        
        if count >= max_seats:
            print("No available seats for the selected train and date.")
            return

        # Insert booking record
        cursor.execute("INSERT INTO Bookings (TrainID, PassengerName, TravelDate, Class, Status) VALUES (%s, %s, %s, %s, %s)",
                       (train_id, passenger_name, travel_date, ticket_class, 'Confirmed'))
        db.commit()
        print("Ticket booked successfully!")

    except Exception as e:
        print("Error:", e)

# Task 2: Reservation Cancellation
def cancel_booking(booking_id):
    try:
        cursor.execute("UPDATE Bookings SET Status = 'Cancelled' WHERE BookingID = %s", (booking_id,))
        db.commit()
        print("Booking cancelled successfully!")

    except Exception as e:
        print("Error:", e)

# Task 3: Fare Checking
def check_fare(train_id, ticket_class):
    try:
        cursor.execute("SELECT FareAmount FROM Fares WHERE TrainID = %s AND Class = %s", (train_id, ticket_class))
        fare = cursor.fetchone()[0]
        print("Fare for the selected class:", fare)

    except Exception as e:
        print("Error:", e)

# Task 4: Booking History
def booking_history(passenger_name):
    try:
        cursor.execute("SELECT * FROM Bookings WHERE PassengerName = %s", (passenger_name,))
        bookings = cursor.fetchall()
        
        if not bookings:
            print("No booking history found for the passenger.")
        else:
            for booking in bookings:
                print("BookingID:", booking[0])
                print("TrainID:", booking[1])
                print("PassengerName:", booking[2])
                print("TravelDate:", booking[3])
                print("Class:", booking[4])
                print("Status:", booking[5])
                print()

    except Exception as e:
        print("Error:", e)

# Task 5: Train Availability
def train_availability(source_station, destination_station):
    try:
        cursor.execute("SELECT * FROM Trains WHERE SourceStation = %s AND DestinationStation = %s",
                       (source_station, destination_station))
        available_trains = cursor.fetchall()
        
        if not available_trains:
            print("No available trains for the selected route.")
        else:
            for train in available_trains:
                print("TrainID:", train[0])
                print("TrainName:", train[1])
                print("DepartureTime:", train[2])
                print("ArrivalTime:", train[3])
                print()

    except Exception as e:
        print("Error:", e)

# Task 6: Menu and User Interaction (Sample Menu)
while True:
    print("Railway Management System")
    print("1. Book Ticket")
    print("2. Cancel Booking")
    print("3. Check Fare")
    print("4. Booking History")
    print("5. Train Availability")
    print("6. Exit")
    
    choice = input("Enter your choice: ")

    if choice == '1':
        train_id = input("Enter TrainID: ")
        passenger_name = input("Enter Passenger Name: ")
        travel_date = input("Enter Travel Date (YYYY-MM-DD): ")
        ticket_class = input("Enter Class: ")
        book_ticket(train_id, passenger_name, travel_date, ticket_class)
    
    elif choice == '2':
        booking_id = input("Enter BookingID to cancel: ")
        cancel_booking(booking_id)

    elif choice == '3':
        train_id = input("Enter TrainID: ")
        ticket_class = input("Enter Class: ")
        check_fare(train_id, ticket_class)

    elif choice == '4':
        passenger_name = input("Enter Passenger Name: ")
        booking_history(passenger_name)

    elif choice == '5':
        source_station = input("Enter Source Station: ")
        destination_station = input("Enter Destination Station: ")
        train_availability(source_station, destination_station)

    elif choice == '6':
        break
db.close()
# Out:
# Railway Management System
# 1. Book Ticket
# 2. Cancel Booking
# 3. Check Fare
# 4. Booking History
# 5. Train Availability
# 6. Exit
# Enter your choice: 5
# Enter Source Station: bangalore
# Enter Destination Station: delhi
# TrainID: 1
# TrainName: vande bharat
# DepartureTime: 8:00:00
# ArrivalTime: 12:00:00
#
# Railway Management System
# 1. Book Ticket
# 2. Cancel Booking
# 3. Check Fare
# 4. Booking History
# 5. Train Availability
# 6. Exit
# Enter your choice: 5
# Enter Source Station: hubli
# Enter Destination Station: pune
# TrainID: 2
# TrainName: shatabdi
# DepartureTime: 9:30:00
# ArrivalTime: 13:30:00
#
# Railway Management System
# 1. Book Ticket
# 2. Cancel Booking
# 3. Check Fare
# 4. Booking History
# 5. Train Availability
# 6. Exit
# Enter your choice: 6
