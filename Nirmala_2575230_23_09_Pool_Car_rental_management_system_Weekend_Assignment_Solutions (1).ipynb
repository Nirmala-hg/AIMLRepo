# %% [markdown]
# # 1. A pool Car rental Management system
#
# A person who has a plan to start a car rental business system in Goa, since Goa is tourist place, where most of peoples are comes here to enjoy their holiday from various regions of India and across the globe. For that the businessperson is approaching you to develop a Car Rental Management System in Python using Object Oriented Programming (OOP). This project should be seen easy design for the customer to access the features as hassle free. Also, administrator access is to be simple and dynamic in nature to update the key attributes of the functionality in this project.
#
# The customer should find the following information from this project as given below,
#
# The total number of cars.
#
# Variety of cars (basic, mid-range, luxury).
#
# Should display the car manufacturer details.
#
# Tariff of each segment of car variety
#
# The availability of the cars with respect to the different segment.
#
# Duration of the car rental must be displayed. Terms and conditions are clearly mentioned.
#
# Car age, kilometre driven, last service date, service history
#
# The car rental businessman is seeking below features,
#
# Dynamically update feature should be available Adding new car to the existing list.
#
# Removing the car from the list if the car is not good condition.
#
# If the car reaches the threshold distance, it should be removed from the
#
# carpool to get servicing.
#
# Rental of the car should be maintained and calculated dynamically. Customer driven extra kilometre; alerts should be given.
#
# If anything needs to be added for effectiveness of the project, you can do it.

# %%
class Car:
    def __init__(self, manufacturer, model, segment, tariff, availability, age, km_driven, last_service_date, service_history):
        self.manufacturer = manufacturer
        self.model = model
        self.segment = segment
        self.tariff = tariff
        self.availability = availability
        self.age = age
        self.km_driven = km_driven
        self.last_service_date = last_service_date
        self.service_history = service_history

class CarRentalSystem:
    def __init__(self):
        self.cars = []

    def add_car(self, car):
        self.cars.append(car)

    def remove_car(self, car):
        self.cars.remove(car)

    def get_total_cars(self):
        return len(self.cars)

    def get_car_varieties(self):
        return list(set(car.segment for car in self.cars))

    def get_car_manufacturer_details(self):
        return [(car.manufacturer, car.model) for car in self.cars]

    def get_car_tariff(self, segment):
        return [car.tariff for car in self.cars if car.segment == segment]

    def get_available_cars(self, segment):
        return [car for car in self.cars if car.segment == segment and car.availability]

    def get_car_duration(self, car):
        # Calculate duration based on rental start and end dates
        pass

    def update_car_availability(self, car, availability):
        car.availability = availability

    def update_car_service_history(self, car, service_history):
        car.service_history = service_history

    def calculate_rental_cost(self, car, duration):
        # Calculate rental cost based on car tariff and duration
        pass

    def alert_extra_kilometers(self, car, extra_kilometers):
        # Send alert to customer if they have driven extra kilometers
        pass


# Create an instance of the CarRentalSystem
car_rental_system = CarRentalSystem()

# Add some sample cars to the system
car1 = Car(input("Enter manufacturer for car1: "), input("Enter model for car1: "), input("Enter segment for car1: "), int(input("Enter tariff for car1: ")), bool(input("Enter availability for car1 (True/False): ")), int(input("Enter age for car1: ")), int(input("Enter km driven for car1: ")), input("Enter last service date for car1: "), input("Enter service history for car1: "))
car2 = Car(input("Enter manufacturer for car2: "), input("Enter model for car2: "), input("Enter segment for car2: "), int(input("Enter tariff for car2: ")), bool(input("Enter availability for car2 (True/False): ")), int(input("Enter age for car2: ")), int(input("Enter km driven for car2: ")), input("Enter last service date for car2: "), input("Enter service history for car2: "))
car3 = Car(input("Enter manufacturer for car3: "), input("Enter model for car3: "), input("Enter segment for car3: "), int(input("Enter tariff for car3: ")), bool(input("Enter availability for car3 (True/False): ")), int(input("Enter age for car3: ")), int(input("Enter km driven for car3: ")), input("Enter last service date for car3: "), input("Enter service history for car3: "))

car_rental_system.add_car(car1)
car_rental_system.add_car(car2)
car_rental_system.add_car(car3)

# Print the total number of cars
print("Total number of cars:", car_rental_system.get_total_cars())

# Print the car varieties
print("Car varieties:", car_rental_system.get_car_varieties())

# Print the car manufacturer details
print("Car manufacturer details:", car_rental_system.get_car_manufacturer_details())

# Print the car tariff for a specific segment
segment = input("Enter segment to get tariff: ")
print("Tariff for", segment, "segment:", car_rental_system.get_car_tariff(segment))

# Print the available cars for a specific segment
segment = input("Enter segment to get available cars: ")
print("Available cars for", segment, "segment:")
available_cars = car_rental_system.get_available_cars(segment)
for car in available_cars:
    print(car.manufacturer, car.model)

# Update the availability of a car
car_to_update = car1
new_availability = bool(input("Enter new availability for car1 (True/False): "))
car_rental_system.update_car_availability(car_to_update, new_availability)
print("Updated availability of", car_to_update.manufacturer, car_to_update.model, ":", car_to_update.availability)

# Update the service history of a car
car_to_update = car2
new_service_history = input("Enter new service history for car2: ")
car_rental_system.update_car_service_history(car_to_update, new_service_history)
print("Updated service history of", car_to_update.manufacturer, car_to_update.model, ":", car_to_update.service_history)
# Out:
# Enter manufacturer for car1: honda
# Enter model for car1: civic
# Enter segment for car1: basic
# Enter tariff for car1: 2000
# Enter availability for car1 (True/False): true
# Enter age for car1: 2
# Enter km driven for car1: 50000
# Enter last service date for car1: 2022-01-01
# Enter service history for car1: Not done
# Enter manufacturer for car2: Toyata
# Enter model for car2: corlia
# Enter segment for car2: Mid range
# Enter tariff for car2: 3000
# Enter availability for car2 (True/False): True
# Enter age for car2: 3
# Enter km driven for car2: 600000
# Enter last service date for car2: 2021-12-01
# Enter service history for car2: Service history 2
# Enter manufacturer for car3:  Maruthi
# Enter model for car3: Swift
# Enter segment for car3:  Basic
# Enter tariff for car3: 2500
# Enter availability for car3 (True/False): false
# Enter age for car3: 1
# Enter km driven for car3: 40000
# Enter last service date for car3: 2022-02-1
# Enter service history for car3: Service history 3
# Total number of cars: 3
# Car varieties: [' Basic', 'Mid range', 'basic']
# Car manufacturer details: [('honda', 'civic'), ('Toyata', 'corlia'), (' Maruthi', 'Swift')]
# Enter segment to get tariff: basic
# Tariff for basic segment: [2000]
# Enter segment to get available cars: basic
# Available cars for basic segment:
# honda civic
# Enter new availability for car1 (True/False): true
# Updated availability of honda civic : True
# Enter new service history for car2: 3
# Updated service history of Toyata corlia : 3
